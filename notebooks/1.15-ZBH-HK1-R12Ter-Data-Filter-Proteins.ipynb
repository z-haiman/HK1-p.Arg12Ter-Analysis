# %% [markdown]
# # Filter proteins for visualization
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from hk1_r12ter_analysis.config import INTERIM_DATA_DIR, PROCESSED_DATA_DIR, logger
from hk1_r12ter_analysis.io import (
    load_dataframe_from_file,
    make_filename,
    save_dataframe_to_file,
)

# %% [markdown]
# ## Load and filter data

# %%
sample_key = "Sample"
group_key = "Group"
# Corresponds to membership of the KEGG pathways
protein_list = [
    "AARS1",  # Aminoacyl-tRNA biosynthesis
    "ACAT1",  # Pyruvate metabolism, Glyoxylate and dicarboxylate metabolism
    "ACAT2",  # Pyruvate metabolism, Glyoxylate and dicarboxylate metabolism
    "ACLY",  # Citrate cycle (TCA cycle)
    "ACO1",  # Citrate cycle (TCA cycle), Glyoxylate and dicarboxylate metabolism
    "ACYP1",  # Pyruvate metabolism
    "ADH5",  # Glycolysis or Gluconeogenesis, Pyruvate metabolism
    "ADK",  # Purine metabolism
    "ADSL",  # Purine metabolism
    "AK1",  # Purine metabolism
    "AK2",  # Purine metabolism
    "AKR1A1",  # Glycolysis or Gluconeogenesis, Pyruvate metabolism
    "AKR1B1",  # Fructose and mannose metabolism
    "ALDH1B1",  # Glycolysis or Gluconeogenesis, Pyruvate metabolism, Arginine and proline metabolism
    "ALDH3B1",  # Glycolysis or Gluconeogenesis
    "ALDH9A1",  # Glycolysis or Gluconeogenesis, Pyruvate metabolism, Arginine and proline metabolism
    "ALDOA",  # Glycolysis or Gluconeogenesis, Pentose phosphate pathway, Fructose and mannose metabolism
    "ALDOC",  # Glycolysis or Gluconeogenesis. Pentose phosphate pathway, Fructose and mannose metabolism
    "AMPD3",  # Purine metabolism
    "APRT",  # Purine metabolism
    "ARG1",  # Arginine biosynthesis, Arginine and proline metabolism
    "ASL",  # Arginine biosynthesis
    "ATIC",  # Purine metabolism
    "BPGM",  # Glycolysis or Gluconeogenesis
    "CARS1",  # Aminoacyl-tRNA biosynthesis
    "CARS2",  # Aminoacyl-tRNA biosynthesis
    "CAT",  # Glyoxylate and dicarboxylate metabolism
    "CHAC2",  # Glutathione metabolism
    "CNDP1",  # Arginine and proline metabolism
    "CNDP2",  # Arginine and proline metabolism
    "CS",  # Citrate cycle (TCA cycle), Glyoxylate and dicarboxylate metabolism
    "DARS1",  # Aminoacyl-tRNA biosynthesis
    "DERA",  # Pentose phosphate pathway
    "ENO1",  # Glycolysis or Gluconeogenesis
    "ENO2",  # Glycolysis or Gluconeogenesis
    "ENO3",  # Glycolysis or Gluconeogenesis
    "ENOSF1",  # Fructose and mannose metabolism
    "FARSB",  # Aminoacyl-tRNA biosynthesis
    "FH",  # Pyruvate metabolism, Citrate cycle (TCA cycle)
    "G6PD",  # Glutathione metabolism, Pentose phosphate pathway
    "GAPDH",  # Glycolysis or Gluconeogenesis
    "GCLC",  # Glutathione metabolism
    "GCLM",  # Glutathione metabolism
    "GGCT",  # Glutathione metabolism
    "GLO1",  # Pyruvate metabolism
    "GMDS",  # Fructose and mannose metabolism
    "GMPPA",  # Fructose and mannose metabolism
    "GMPPB",  # Fructose and mannose metabolism
    "GMPR",  # Purine metabolism
    "GMPR2",  # Purine metabolism
    "GMPS",  # Purine metabolism
    "GOT1",  # Arginine biosynthesis, Arginine and proline metabolism
    "GPI",  # Glycolysis or Gluconeogenesis, Pentose phosphate pathway
    "GPX1",  # Glutathione metabolism
    "GPX3",  # Glutathione metabolism
    "GPX4",  # Glutathione metabolism
    "GRHPR",  # Pyruvate metabolism, Glyoxylate and dicarboxylate metabolism
    "GSR",  # Glutathione metabolism
    "GSS",  # Glutathione metabolism
    "GSTM2",  # Glutathione metabolism
    "GSTM3",  # Glutathione metabolism
    "GSTO1",  # Glutathione metabolism
    "GSTP1",  # Glutathione metabolism
    "GUK1",  # Purine metabolism
    "HAGH",  # Pyruvate metabolism
    "HDDC2",  # Purine metabolism
    "HK1",  # Glycolysis or Gluconeogenesis, Fructose and mannose metabolism
    "HPRT1",  # Purine metabolism
    "IDH1",  # Glutathione metabolism, Citrate cycle (TCA cycle)
    "IDH2",  # Glutathione metabolism, Citrate cycle (TCA cycle)
    "LANCL1",  # Glutathione metabolism
    "LAP3",  # Glutathione metabolism, Arginine and proline metabolism
    "LDHA",  # Glycolysis or Gluconeogenesis, Pyruvate metabolism
    "LDHB",  # Glycolysis or Gluconeogenesis, Pyruvate metabolism
    "MDH1",  # Pyruvate metabolism, Citrate cycle (TCA cycle), Glyoxylate and dicarboxylate metabolism
    "MDH2",  # Pyruvate metabolism, Citrate cycle (TCA cycle), Glyoxylate and dicarboxylate metabolism
    "ME2",  # Pyruvate metabolism
    "MGST3",  # Glutathione metabolism
    "NME1",  # Purine metabolism
    "NME2",  # Purine metabolism
    "NT5C",  # Purine metabolism
    "NUDT5",  # Purine metabolism
    "OAT",  # Arginine and proline metabolism
    "PAICS",  # Purine metabolism
    "PFAS",  # Purine metabolism
    "PFKL",  # Glycolysis or Gluconeogenesis, Pentose phosphate pathway, Fructose and mannose metabolism
    "PFKM",  # Glycolysis or Gluconeogenesis, Pentose phosphate pathway, Fructose and mannose metabolism
    "PFKP",  # Glycolysis or Gluconeogenesis, Pentose phosphate pathway, Fructose and mannose metabolism
    "PGAM1",  # Glycolysis or Gluconeogenesis
    "PGD",  # Glutathione metabolism, Pentose phosphate pathway
    "PGK1",  # Glycolysis or Gluconeogenesis
    "PGLS",  # Pentose phosphate pathway
    "PGM1",  # Glycolysis or Gluconeogenesis, Pentose phosphate pathway, Purine metabolism
    "PGM2",  # Glycolysis or Gluconeogenesis, Pentose phosphate pathway,  Purine metabolism
    "PGP",  # Glyoxylate and dicarboxylate metabolism
    "PKLR",  # Glycolysis or Gluconeogenesis, Pyruvate metabolism
    "PKM",  # Glycolysis or Gluconeogenesis,  Pyruvate metabolism
    "PNP",  # Purine metabolism
    "PRDX6",  # Glutathione metabolism
    "PRPS1",  # Pentose phosphate pathway, Purine metabolism
    "PRPS1L1",  # Pentose phosphate pathway, Purine metabolism
    "PRUNE1",  # Purine metabolism
    "PYCR3",  # Arginine and proline metabolism
    "QARS1",  # Aminoacyl-tRNA biosynthesis
    "RARS1",  # Aminoacyl-tRNA biosynthesis
    "RBKS",  # Pentose phosphate pathway
    "RPE",  # Pentose phosphate pathway
    "RPIA",  # Pentose phosphate pathway
    "RRM1",  # Glutathione metabolism, Purine metabolism
    "SARS1",  # Aminoacyl-tRNA biosynthesis
    "SHPK",  # Pentose phosphate pathway
    "SORD",  # Fructose and mannose metabolism
    "TALDO1",  # Pentose phosphate pathway
    "TKFC",  # Fructose and mannose metabolism
    "TKT",  # Pentose phosphate pathway
    "TPI1",  # Glycolysis or Gluconeogenesis, Fructose and mannose metabolism
    "WARS1",  # Aminoacyl-tRNA biosynthesis
    "YARS1",  # Aminoacyl-tRNA biosynthesis
]

# %%
source_type = "RBC"
data_type = "Proteins"
value_type = "Intensities"
input_dirpath = PROCESSED_DATA_DIR / "HK1-R12Ter" / "Normalized"
output_dirpath = PROCESSED_DATA_DIR / "HK1-R12Ter" / "Normalized"

index_cols = [key for key in [sample_key, group_key] if key]
for norm_str in ["none-none-none", "median-none-none", "median-none-auto"]:
    input_dirpath_norm = input_dirpath / norm_str
    output_dirpath_norm = output_dirpath / norm_str

    logger.debug(f"Processing data for '{source_type}-{data_type}'...")
    filename = make_filename(source_type, data_type, value_type)
    df = load_dataframe_from_file(input_dirpath_norm / filename, index_col=index_cols)
    logger.debug(f"Filtering data for '{source_type}-{data_type}'...")
    df = df.loc[:, protein_list]
    logger.info(f"Filtered data for '{source_type}-{data_type}'")

    # Save processed data
    filename = make_filename(source_type, data_type, "Filtered", value_type)
    save_dataframe_to_file(df, output_dirpath_norm / filename, index=True)
    logger.info(f"Processed data for '{source_type}-{data_type}'.")
